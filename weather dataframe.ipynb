# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Weather Dataset.csv")
#csv file must be with the notebook in the same file

# %%
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 3775  2006-08-11 02:00:00.000 +0200  Mostly Cloudy        rain
# 3776  2006-12-26 12:00:00.000 +0100  Partly Cloudy        rain
# 3777  2006-12-19 20:00:00.000 +0100       Overcast        rain
# 3778  2006-12-10 11:00:00.000 +0100  Partly Cloudy        rain
# 3779  2006-12-10 15:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.isnull().sum()
#no null values
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
df.dtypes
#checking the data types
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df.duplicated()
#there is duplicated rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3775     True
# 3776     True
# 3777     True
# 3778     True
# 3779     True
# Length: 3780, dtype: bool

# %%
df.drop_duplicates(inplace=True)
#removed duplicated rows (which appeared second)

# %%
df.drop(columns='Loud Cover',inplace=True)
#taking in consider that loud cover in any calculations = const = 0

# %%
df
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
# 3247  2006-08-23 18:00:00.000 +0200  Partly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.drop_duplicates(subset=['Formatted Date'],inplace=True)
#dropping duplicated times with differnt data

# %%
df.shape
# Out:
# (2520, 11)

# %%
df['Humidity']=df['Humidity'].where(df['Humidity'] > 0 , other = np.nan)
#replacing unrealistic values in humidity

# %%
df.min()
#getting the lowest values
# Out:
# Formatted Date              2006-02-01 00:00:00.000 +0100
# Summary                          Breezy and Mostly Cloudy
# Precip Type                                          rain
# Temperature (C)                                   -2000.0
# Apparent Temperature (C)                       -11.911111
# Humidity                                             0.32
# Wind Speed (km/h)                                     0.0
# Wind Bearing (degrees)                                0.0
# Visibility (km)                                   -2000.0
# Pressure (millibars)                                  0.0
# Daily Summary                       Foggy in the evening.
# dtype: object

# %%
df['Temperature (C)']=df['Temperature (C)'].where(df['Temperature (C)'] > -52 , other = np.nan)
#replacing unrealistic values in temp

# %%
df['Visibility (km)']=df['Visibility (km)'].where(df['Visibility (km)'] > .050 , other = np.nan)
#replacing unrealistic values in visibility

# %%
df.max()
#no unrealistic values
# Out:
# Formatted Date              2006-12-31 23:00:00.000 +0100
# Summary                                     Partly Cloudy
# Precip Type                                          snow
# Temperature (C)                                 32.638889
# Apparent Temperature (C)                        35.494444
# Humidity                                              1.0
# Wind Speed (km/h)                                  36.386
# Wind Bearing (degrees)                              359.0
# Visibility (km)                                      16.1
# Pressure (millibars)                              1042.31
# Daily Summary                  Partly cloudy until night.
# dtype: object

# %%
df.plot('Formatted Date' , 'Temperature (C)')
plt.xlabel('dates')
# Out:
# Text(0.5, 0, 'dates')

# %%
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure

# %%
plt.hist(df['Temperature (C)'],bins=50 )
plt.xlabel('temp')
plt.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')

# %%
plt.scatter(df['Temperature (C)'],df['Humidity'])
plt.xlabel('temp')
plt.ylabel('humidity')
# Out:
# Text(0, 0.5, 'humidity')

# %%
import seaborn as sns

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df2=df

# %%
df2
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2515  2006-02-20 19:00:00.000 +0100  Partly Cloudy        rain
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df2['Daily Summary'] = le.fit_transform(df['Daily Summary'])

# %%
df2['Summary'] = le.fit_transform(df['Summary'])

# %%
df2['Precip Type'] = le.fit_transform(df['Precip Type'])

# %%
df2['Formatted Date'] = le.fit_transform(df['Formatted Date'])

# %%
#givin each non-numerical number a key indicating it to use df2 in colleration matrix
df2.dtypes
# Out:
# Formatted Date                int32
# Summary                       int32
# Precip Type                   int32
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Pressure (millibars)        float64
# Daily Summary                 int32
# dtype: object

# %%
mat=df.corr()
#correlation map to state how far each attribute is realted to the others

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(mat, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
